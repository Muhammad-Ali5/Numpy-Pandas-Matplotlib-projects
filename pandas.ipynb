# %% [markdown]
# # Pandas Operation

# %%
import pandas as pd

# %%
covid_dataset = pd.read_csv("covid-liver.csv", encoding="ISO-8859-1")

# %% [markdown]
# # Data Manipulation

# %%
'''
head()
tail()
info 
describe 
drop 
dropna 
join 
groupby 

'''
# Out:
# '\nhead()\ntail()\ninfo \ndescribe \ndrop \ndropna \njoin \ngroupby \n\n'

# %%
covid_dataset.head(5)
# Out:
#   Cancer         Year  Month Bleed Mode_Presentation  Age Gender Etiology  \
# 0      Y  Prepandemic      1     N      Surveillance   68      M    NAFLD
# 1      Y  Prepandemic      1     N      Surveillance   70      M     ARLD
# 2      Y  Prepandemic      1     N      Surveillance   64      M     ARLD
# 3      Y  Prepandemic      1     N        Incidental   73      M     ARLD
# 4      Y  Prepandemic      1     N        Incidental   66      F     ARLD
#
#   Cirrhosis  Size  ... Surveillance_programme Surveillance_effectiveness  \
# 0         Y  22.0  ...                      Y                 Consistent
# 1         Y  40.0  ...                      Y                 Consistent
# 2         Y  52.0  ...                      Y                 Consistent
# 3         Y  80.0  ...                      N                        NaN
# 4         Y  60.0  ...                      N                        NaN
#
#   Mode_of_surveillance_detection Time_diagnosis_1st_Tx  \
# ...

# %%
covid_dataset.shape
# Out:
# (450, 27)

# %%
covid_dataset.describe()
# Out:
#             Month         Age        Size  Survival_fromMDM  \
# count  450.000000  450.000000  400.000000        450.000000
# mean     6.757778   70.371111   53.355000         12.696622
# std      3.449476   10.572586   40.283257          9.703300
# min      1.000000   27.000000   10.000000         -0.030000
# 25%      4.000000   65.000000   24.000000          4.032500
# 50%      7.000000   72.000000   40.000000         10.785000
# 75%     10.000000   78.000000   70.500000         21.282500
# max     12.000000   96.000000  220.000000         32.770000
#
#        Time_diagnosis_1st_Tx          PS  Time_MDM_1st_treatment  \
# count             158.000000  448.000000              162.000000
# mean               -6.570380    1.225446                2.385988
# std               114.312876    1.030008                2.103355
# min             -1434.070000    0.000000               -0.870000
# 25%                 1.207500    0.000000                1.185000
# ...

# %%
covid_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cancer                              450 non-null    object
#  1   Year                                450 non-null    object
#  2   Month                               450 non-null    int64
#  3   Bleed                               310 non-null    object
#  4   Mode_Presentation                   450 non-null    object
#  5   Age                                 450 non-null    int64
#  6   Gender                              450 non-null    object
#  7   Etiology                            311 non-null    object
#  8   Cirrhosis                           311 non-null    object
#  9   Size                                400 non-null    float64
#  10  HCC_TNM_Stage                       311 non-null    object
# ...

# %%
# check missing value 
covid_dataset.isnull().sum()
# Out:
# Cancer                                  0
# Year                                    0
# Month                                   0
# Bleed                                 140
# Mode_Presentation                       0
# Age                                     0
# Gender                                  0
# Etiology                              139
# Cirrhosis                             139
# Size                                   50
# HCC_TNM_Stage                         139
# HCC_BCLC_Stage                        139
# ICC_TNM_Stage                         311
# Treatment_grps                          2
# Survival_fromMDM                        0
# Alive_Dead                              0
# Type_of_incidental_finding            326
# Surveillance_programme                139
# Surveillance_effectiveness            333
# Mode_of_surveillance_detection        352
# Time_diagnosis_1st_Tx                 292
# Date_incident_surveillance_scan       417
# ...

# %%
# fill the missing value  
covid_dataset.fillna(method="ffill", limit=5)
# Out:
# C:\Users\Dubai Computers\AppData\Local\Temp\ipykernel_2404\2741714144.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   covid_dataset.fillna(method="ffill", limit=5)
#     Cancer         Year  Month Bleed Mode_Presentation  Age Gender Etiology  \
# 0        Y  Prepandemic      1     N      Surveillance   68      M    NAFLD
# 1        Y  Prepandemic      1     N      Surveillance   70      M     ARLD
# 2        Y  Prepandemic      1     N      Surveillance   64      M     ARLD
# 3        Y  Prepandemic      1     N        Incidental   73      M     ARLD
# 4        Y  Prepandemic      1     N        Incidental   66      F     ARLD
# ..     ...          ...    ...   ...               ...  ...    ...      ...
# 445      N     Pandemic     12   NaN       Symptomatic   72      F      NaN
# 446      N     Pandemic     12   NaN       Symptomatic   63      M      NaN
# ...

# %%
# fill missing value  
covid_dataset.fillna(method="bfill", limit=5)
# Out:
# C:\Users\Dubai Computers\AppData\Local\Temp\ipykernel_2404\2147649207.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   covid_dataset.fillna(method="bfill", limit=5)
#     Cancer         Year  Month Bleed Mode_Presentation  Age Gender Etiology  \
# 0        Y  Prepandemic      1     N      Surveillance   68      M    NAFLD
# 1        Y  Prepandemic      1     N      Surveillance   70      M     ARLD
# 2        Y  Prepandemic      1     N      Surveillance   64      M     ARLD
# 3        Y  Prepandemic      1     N        Incidental   73      M     ARLD
# 4        Y  Prepandemic      1     N        Incidental   66      F     ARLD
# ..     ...          ...    ...   ...               ...  ...    ...      ...
# 445      N     Pandemic     12   NaN       Symptomatic   72      F      NaN
# 446      N     Pandemic     12   NaN       Symptomatic   63      M      NaN
# ...

# %%
# covid_dataset.dropna(axis=0, thresh=None, subset=None)

# %%
covid_dataset["Age"] > 20
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 445    True
# 446    True
# 447    True
# 448    True
# 449    True
# Name: Age, Length: 450, dtype: bool

# %%
(covid_dataset["Age"] > 20) & (covid_dataset["Months_from_last_surveillance"] <5)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 445    False
# 446    False
# 447    False
# 448    False
# 449    False
# Length: 450, dtype: bool

# %%
covid_dataset.head()
# Out:
#   Cancer         Year  Month Bleed Mode_Presentation  Age Gender Etiology  \
# 0      Y  Prepandemic      1     N      Surveillance   68      M    NAFLD
# 1      Y  Prepandemic      1     N      Surveillance   70      M     ARLD
# 2      Y  Prepandemic      1     N      Surveillance   64      M     ARLD
# 3      Y  Prepandemic      1     N        Incidental   73      M     ARLD
# 4      Y  Prepandemic      1     N        Incidental   66      F     ARLD
#
#   Cirrhosis  Size  ... Surveillance_programme Surveillance_effectiveness  \
# 0         Y  22.0  ...                      Y                 Consistent
# 1         Y  40.0  ...                      Y                 Consistent
# 2         Y  52.0  ...                      Y                 Consistent
# 3         Y  80.0  ...                      N                        NaN
# 4         Y  60.0  ...                      N                        NaN
#
#   Mode_of_surveillance_detection Time_diagnosis_1st_Tx  \
# ...

# %%
covid_dataset.notnull()
# Out:
#      Cancer  Year  Month  Bleed  Mode_Presentation   Age  Gender  Etiology  \
# 0      True  True   True   True               True  True    True      True
# 1      True  True   True   True               True  True    True      True
# 2      True  True   True   True               True  True    True      True
# 3      True  True   True   True               True  True    True      True
# 4      True  True   True   True               True  True    True      True
# ..      ...   ...    ...    ...                ...   ...     ...       ...
# 445    True  True   True  False               True  True    True     False
# 446    True  True   True  False               True  True    True     False
# 447    True  True   True  False               True  True    True     False
# 448    True  True   True  False               True  True    True     False
# 449    True  True   True  False               True  True    True     False
#
#      Cirrhosis   Size  ...  Surveillance_programme  \
# ...

# %%
covid_dataset.to_csv("Covid-liver-pandas_operation.csv")
